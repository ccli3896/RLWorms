# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import numpy as np
import utils as ut

# %%
with open('Data/Reals20-12-14-58/realworm_init_df.pkl','rb') as f:
    traj_df = pickle.load(f)

# %%
dd = ut.make_dist_dict(traj_df, sm_pars=None,
    prev_act_window=1,
    cut_reversals=True)

# %%
dd.keys()
# Out:
# dict_keys(['body_on', 'body_off', 'head_on', 'head_off', 'reward_on', 'reward_off'])

# %%
plt.imshow(np.sqrt(dd['reward_on'][:,:,1]))
plt.colorbar();

# %%
traj_dict['obs'][i][0] # body angle relative to target
# Out:
# [array([0.66666667, 0.16666667]),
#  array([0.66666667, 0.        ]),
#  array([0.66666667, 0.        ]),
#  array([0.66666667, 0.16666667]),
#  array([0.66666667, 0.        ]),
#  array([0.66666667, 0.        ]),
#  array([ 0.66666667, -0.16666667]),
#  array([ 0.66666667, -0.16666667]),
#  array([ 0.66666667, -0.16666667]),
#  array([ 0.66666667, -0.16666667]),
#  array([ 0.66666667, -0.16666667]),
#  array([ 0.66666667, -0.16666667]),
#  array([ 0.66666667, -0.16666667]),
#  array([ 0.66666667, -0.16666667]),
#  array([ 0.66666667, -0.16666667]),
#  array([0.66666667, 0.        ]),
#  array([-0.33333333, -0.16666667]),
#  array([-0.33333333, -0.16666667]),
#  array([-0.33333333,  0.        ]),
#  array([-0.33333333, -0.16666667]),
#  array([-0.33333333,  0.        ]),
#  array([-0.33333333,  0.33333333]),
#  array([-0.33333333,  0.33333333]),
#  array([-0.33333333,  0.33333333]),
#  array([-0.33333333,  0.33333333]),
#  array([-0.33333333,  0.33333333]),
# ...

# %%
endpts[0,:]
# Out:
# array([969., 986., 827., 821.])

# %%
thetab = np.zeros((6000))
for i,pt in enumerate(traj_dict['obs']):
    thetab[i] = traj_dict['obs'][i][0]

# %%
plt.plot(thetab[:100]*180)

# %%
traj_dict['t']
# Out:
# [0.4369999999762513,
#  0.6089999999967404,
#  0.7809999999590218,
#  0.9689999999827705,
#  1.1559999999590218,
#  1.327999999979511,
#  1.5149999999557622,
#  1.6869999999762513,
#  1.875,
#  2.030999999959022,
#  2.2189999999827705,
#  2.4219999999622814,
#  2.5939999999827705,
#  2.780999999959022,
#  2.952999999979511,
#  3.139999999955762,
#  3.3119999999762513,
#  3.5,
#  3.6719999999622814,
#  3.8589999999967404,
#  4.030999999959022,
#  4.2189999999827705,
#  4.421999999962281,
#  4.60899999999674,
#  4.780999999959022,
#  4.952999999979511,
#  5.139999999955762,
#  5.327999999979511,
#  5.5,
#  5.686999999976251,
#  5.85899999999674,
#  6.046999999962281,
#  6.2189999999827705,
#  6.405999999959022,
#  6.577999999979511,
#  6.764999999955762,
#  6.936999999976251,
#  7.125,
#  7.311999999976251,
#  7.48399999999674,
#  7.671999999962281,
#  7.8439999999827705,
#  8.030999999959022,
#  8.23399999999674,
#  8.389999999955762,
#  8.59399999998277,
#  8.764999999955762,
# ...
